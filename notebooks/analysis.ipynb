# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("C:/xampp/htdocs/ai-drug-price/data/original_data_set/meds_price.xlsx")

# %%
print("Records:", len(df))

# 2. Number of columns
print("Columns:", len(df.columns))

# 3. Column names
print("Columns:", df.columns.tolist())

# 4. Missing values
print("\nMissing values:")
print(df.isnull().sum())

# 5. Duplicate records
print("\nDuplicates:", df.duplicated().sum())

# 6. Basic statistics
print("\nStatistics:")
print(df.describe())

# 7. Price distribution
print("\nPrice distribution:")
print(df["Price"].describe())
# Out:
# Records: 51216
# Columns: 8
# Columns: ['Generic Name', 'Strength', 'Pack Size', 'Price', 'Name of the Manufacturer', 'Brand Name', 'Dosage Description', 'Use For']
#
# Missing values:
# Generic Name                0
# Strength                    0
# Pack Size                   0
# Price                       0
# Name of the Manufacturer    0
# Brand Name                  0
# Dosage Description          0
# Use For                     0
# dtype: int64
#
# Duplicates: 51
#
# Statistics:
#                Price
# count   51216.000000
# mean      107.578798
# std      1153.315032
# min         0.100000
# 25%         6.000000
# 50%        12.000000
# 75%        35.110000
# max    126000.000000
#
# Price distribution:
# count     51216.000000
# mean        107.578798
# std        1153.315032
# min           0.100000
# 25%           6.000000
# 50%          12.000000
# 75%          35.110000
# max      126000.000000
# Name: Price, dtype: float64

# %%
print("Generic Names:", df["Generic Name"].nunique())
print("Manufacturers:", df["Name of the Manufacturer"].nunique())
print("Brands:", df["Brand Name"].nunique())
print("Dosage Types:", df["Dosage Description"].nunique())
print("Strengths:", df["Strength"].nunique())
print("Pack Sizes:", df["Pack Size"].nunique())
# Out:
# Generic Names: 1352
# Manufacturers: 174
# Brands: 20138
# Dosage Types: 110
# Strengths: 1066
# Pack Sizes: 2553
